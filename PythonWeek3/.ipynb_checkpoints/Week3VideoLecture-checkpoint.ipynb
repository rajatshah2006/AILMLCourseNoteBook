# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import  plotly.express as px
# %matplotlib inline

pd.set_option('display.float_format',lambda x: '%.3f' %x)

# %%
data=pd.read_csv("Melbourne_Housing.csv")
data.head()
# Out:
#          Suburb  Rooms Type        SellerG        Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson  03-09-2016    13.500  3042.000
# 1   Albert Park      2    h  hockingstuart  03-09-2016     3.300  3206.000
# 2   Albert Park      2    h        Thomson  03-09-2016     3.300  3206.000
# 3    Alphington      4    h          Brace  03-09-2016     6.400  3078.000
# 4    Alphington      3    h         Jellis  03-09-2016     6.400  3078.000
#
#    Bedroom  Bathroom   Car  Landsize BuildingArea  YearBuilt  \
# 0    3.000     2.000 1.000   303.000          225   2016.000
# 1    2.000     1.000 0.000   120.000           82   1900.000
# 2    2.000     1.000 0.000   159.000          inf        NaN
# 3    3.000     2.000 4.000   853.000          263   1930.000
# 4    3.000     2.000 2.000   208.000          inf   2013.000
#
#               Regionname  Propertycount    Price
# 0   Western Metropolitan           3464   840000
# ...

# %%
data.tail()
# Out:
#                  Suburb  Rooms Type    SellerG        Date  Distance  \
# 27109        Noble Park      3    h        C21  30-09-2017    22.700
# 27110         Reservoir      3    u         RW  30-09-2017    12.000
# 27111     Roxburgh Park      4    h      Raine  30-09-2017    20.600
# 27112  Springvale South      3    h  Harcourts  30-09-2017    22.200
# 27113       Westmeadows      4    h      Barry  30-09-2017    16.500
#
#        Postcode  Bedroom  Bathroom   Car  Landsize BuildingArea  YearBuilt  \
# 27109  3174.000    3.000     1.000 6.000   569.000          130   1959.000
# 27110  3073.000    3.000     1.000 1.000       NaN          105   1990.000
# 27111  3064.000    4.000     2.000 2.000       NaN          225   1995.000
# 27112  3172.000    3.000     2.000 1.000   544.000          NaN        NaN
# 27113  3049.000    4.000     2.000 6.000   813.000          140   1960.000
#
#                        Regionname  Propertycount   Price
# ...

# %%
data.shape
# Out:
# (27114, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  object
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10543 non-null  object
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: float64(7), int64(3), object(6)
# memory usage: 3.3+ MB

# %%
data['Date'] = pd.to_datetime(data['Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data['Date'] = pd.to_datetime(data['Date'])
#
# File D:\Software\Lib\site-packages\pandas\core\tools\datetimes.py:1108, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1106             result = arg.tz_localize("utc")
#    1107 elif isinstance(arg, ABCSeries):
# -> 1108     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1109     if not cache_array.empty:
#    1110         result = arg.map(cache_array)
#
# File D:\Software\Lib\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# --> 254     cache_dates = convert_listlike(unique_dates, format)
#     255     # GH#45319
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'],format='mixed',dayfirst=True)

# %%
data['Date'].head()
# Out:
# 0   2016-09-03
# 1   2016-09-03
# 2   2016-09-03
# 3   2016-09-03
# 4   2016-09-03
# Name: Date, dtype: datetime64[ns]

# %%
data['BuildingArea'].apply(type).value_counts()
# Out:
# BuildingArea
# <class 'float'>    27114
# Name: count, dtype: int64

# %%
data['BuildingArea']=data['BuildingArea'].replace(['missing','inf'],np.nan)
data['BuildingArea']=data['BuildingArea'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  datetime64[ns]
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(4)
# ...

# %%
data_new=pd.read_csv("Melbourne_Housing.csv",na_values=['missing','inf'])

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  object
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: float64(8), int64(3), object(5)
# memory usage: 3.3+ MB

# %%
data_new['BuildingArea'].dtype
# Out:
# dtype('float64')

# %%
data['BuildingArea'].unique()
# Out:
# array([ 225.    ,   82.    ,       nan,  263.    ,  242.    ,  251.    ,
#         117.    ,   76.    ,  399.    ,  118.    ,  103.    ,  180.    ,
#         123.    ,  218.    ,  129.    ,  167.    ,  154.    ,  275.    ,
#         121.    ,  125.    ,  255.    ,   75.    ,  156.    ,  240.    ,
#         268.    ,  108.    ,   69.    ,  140.    ,  214.    ,  253.    ,
#         189.    ,  215.    ,   96.    ,  104.    ,  100.    ,  313.    ,
#         144.    ,   93.    ,  110.    ,   70.    ,  122.    ,   51.    ,
#         147.    ,  113.    ,   83.    ,   56.    ,  137.    ,   85.    ,
#          64.    ,  175.    , 3558.    ,  170.    ,  265.    ,  353.    ,
#         138.    ,   19.    ,  116.    ,   87.    ,   74.    ,  320.    ,
#         300.    ,  210.    ,  120.    ,   86.    ,   97.    ,  200.    ,
#         106.    ,   14.    ,  161.    ,  128.    ,  185.    ,  146.    ,
#         133.    ,  115.    ,  143.    ,  150.    ,  195.    ,  236.    ,
# ...

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom           6436
# Bathroom          6442
# Car               6817
# Landsize          9241
# BuildingArea     16585
# YearBuilt        15129
# Regionname           0
# Propertycount        0
# Price                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 11

# %%
data.drop_duplicates(inplace=True)

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.describe().T
# Out:
#                   count                           mean                  min  \
# Rooms         27103.000                          2.992                1.000
# Date              27103  2017-05-23 12:25:09.441759488  2016-01-28 00:00:00
# Distance      27102.000                         11.280                0.000
# Postcode      27102.000                       3113.787             3000.000
# Bedroom       20678.000                          3.046                0.000
# Bathroom      20672.000                          1.592                0.000
# Car           20297.000                          1.716                0.000
# Landsize      17873.000                        560.537               50.000
# BuildingArea  10529.000                        154.512               11.000
# YearBuilt     11985.000                       1966.618             1850.000
# Propertycount 27103.000                       7564.741               83.000
# ...

# %% [markdown]
# # Note
# 50% -- is median
# 25% - 1st Quartile
# 25% - 3rd Quartile

# %%
data['Postcode'].nunique()
# Out:
# 209

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27103 entries, 0 to 27102
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27103 non-null  object
#  1   Rooms          27103 non-null  int64
#  2   Type           27103 non-null  object
#  3   SellerG        27103 non-null  object
#  4   Date           27103 non-null  datetime64[ns]
#  5   Distance       27102 non-null  float64
#  6   Postcode       27102 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27103 non-null  object
#  14  Propertycount  27103 non-null  int64
#  15  Price          27103 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(4)
# ...

# %%
category=['Suburb','Type','SellerG','Regionname']
for column in category:
    print(data[column].value_counts())
    print("-" * 50)
# Out:
# Suburb
# Reservoir         724
# Bentleigh East    493
# Richmond          437
# Preston           410
# Brunswick         383
#                  ...
# Wandin North        1
# Ferny Creek         1
# Tecoma              1
# Montrose            1
# viewbank            1
# Name: count, Length: 345, dtype: int64
# --------------------------------------------------
# Type
# h    18394
# u     5882
# t     2827
# Name: count, dtype: int64
# --------------------------------------------------
# SellerG
# Nelson           2733
# Jellis           2516
# Barry            2385
# hockingstuart    2096
# Ray              1574
#                  ...
# Allan               1
# Jim                 1
# iProperty           1
# Batty               1
# Icon                1
# Name: count, Length: 347, dtype: int64
# --------------------------------------------------
# Regionname
# Southern Metropolitan         8480
# Northern Metropolitan         7809
# Western Metropolitan          5792
# ...

# %%
for column in category:
    print(data[column].value_counts(normalize=True))
    print("-" * 50)
# Out:
# Suburb
# Reservoir        0.027
# Bentleigh East   0.018
# Richmond         0.016
# Preston          0.015
# Brunswick        0.014
#                   ...
# Wandin North     0.000
# Ferny Creek      0.000
# Tecoma           0.000
# Montrose         0.000
# viewbank         0.000
# Name: proportion, Length: 345, dtype: float64
# --------------------------------------------------
# Type
# h   0.679
# u   0.217
# t   0.104
# Name: proportion, dtype: float64
# --------------------------------------------------
# SellerG
# Nelson          0.101
# Jellis          0.093
# Barry           0.088
# hockingstuart   0.077
# Ray             0.058
#                  ...
# Allan           0.000
# Jim             0.000
# iProperty       0.000
# Batty           0.000
# Icon            0.000
# Name: proportion, Length: 347, dtype: float64
# --------------------------------------------------
# Regionname
# Southern Metropolitan        0.313
# Northern Metropolitan        0.288
# ...

# %%
sns.displot(data=data,x="Distance",kind="kde")
# Out:
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=data,x="Distance",kde=True)
# Out:
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Distance', ylabel='Count'>

# %%
sns.histplot(data=data,x='Distance',stat='density')
# Out:
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Distance', ylabel='Density'>

# %%
sns.boxplot(data=data,x="Distance")
# Out:
# <Axes: xlabel='Distance'>

# %%
sns.histplot(data=data,x="Landsize")
# Out:
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Landsize', ylabel='Count'>

# %%
sns.boxplot(data=data,x="Landsize")
# Out:
# <Axes: xlabel='Landsize'>

# %%
sns.displot(data=data,x="Landsize",kind="kde")
# Out:
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(data=data,x=data['Landsize']/100000,kind="kde")
# Out:
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data[data['Landsize']>60000]
# Out:
#              Suburb  Rooms Type    SellerG        Date  Distance  Postcode  \
# 23908        Silvan      3    h  Harcourts  27-05-2017    34.600  3795.000
# 25090  Balwyn North      3    h        Kay  28-08-2016     9.200  3104.000
#
#        Bedroom  Bathroom   Car  Landsize BuildingArea  YearBuilt  \
# 23908    3.000     2.000 2.000 76000.000          NaN        NaN
# 25090    3.000     1.000 2.000 75100.000          NaN        NaN
#
#                   Regionname  Propertycount    Price
# 23908       Eastern Victoria            457  1085000
# 25090  Southern Metropolitan           7809  2000000

# %%
sns.displot(data=data,x='BuildingArea',kind="kde")
# Out:
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(data=data,x='BuildingArea')
# Out:
# <Axes: xlabel='BuildingArea'>

# %%
sns.histplot(data=data,x=data['Price'])
# Out:
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.boxplot(data=data,x=data['Price'])
# Out:
# <Axes: xlabel='Price'>

# %%
sns.boxplot(data=data,x=data['Rooms'])
# Out:
# <Axes: xlabel='Rooms'>

# %%
data.loc[data['Rooms']>7].shape
# Out:
# (23, 16)

# %%
data.loc[data['Rooms']>7]['Type'].value_counts()
# Out:
# Type
# h    21
# u     2
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  datetime64[ns]
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(4)
# ...

# %%
sns.countplot(data=data,x=data['Regionname'])
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Western Metropolitan'),
#   Text(1, 0, 'Southern Metropolitan'),
#   Text(2, 0, 'Northern Metropolitan'),
#   Text(3, 0, 'Eastern Metropolitan'),
#   Text(4, 0, 'South-Eastern Metropolitan'),
#   Text(5, 0, 'Eastern Victoria'),
#   Text(6, 0, 'Northern Victoria'),
#   Text(7, 0, 'Western Victoria')])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  datetime64[ns]
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(4)
# ...

# %%
data[['Rooms','Distance','Postcode','Bedroom','Bathroom','Car','Landsize','BuildingArea','YearBuilt','Propertycount','Price']].corr()
# Out:
#                Rooms  Distance  Postcode  Bedroom  Bathroom    Car  Landsize  \
# Rooms          1.000     0.284     0.081    0.959     0.609  0.394     0.071
# Distance       0.284     1.000     0.490    0.283     0.140  0.245     0.118
# Postcode       0.081     0.490     1.000    0.087     0.124  0.063     0.076
# Bedroom        0.959     0.283     0.087    1.000     0.606  0.396     0.071
# Bathroom       0.609     0.140     0.124    0.606     1.000  0.306     0.055
# Car            0.394     0.245     0.063    0.396     0.306  1.000     0.092
# Landsize       0.071     0.118     0.076    0.071     0.055  0.092     1.000
# BuildingArea   0.418     0.102     0.060    0.413     0.389  0.218     0.058
# YearBuilt     -0.004     0.321     0.100    0.006     0.187  0.133     0.045
# Propertycount -0.080    -0.021     0.024   -0.060    -0.040 -0.014    -0.020
# Price          0.465    -0.211     0.045    0.430     0.431  0.201     0.043
#
# ...

# %%
sns.heatmap(data=data[['Rooms','Distance','Postcode','Bedroom','Bathroom','Car','Landsize','BuildingArea','YearBuilt','Propertycount','Price']].corr().corr(),annot=True,cmap="Spectral",vmin=-1,vmax=1)
# Out:
# <Axes: >

# %%
sns.heatmap(data=data.corr(numeric_only=True),annot=True,cmap="Spectral",vmin=-1,vmax=1)
# Out:
# <Axes: >

# %%
data['TotalSpace']=data['Rooms']+data['Bedroom']+data['Bathroom']+data['Car']

# %%
data.head()
# Out:
#          Suburb  Rooms Type        SellerG       Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson 2016-09-03    13.500  3042.000
# 1   Albert Park      2    h  hockingstuart 2016-09-03     3.300  3206.000
# 2   Albert Park      2    h        Thomson 2016-09-03     3.300  3206.000
# 3    Alphington      4    h          Brace 2016-09-03     6.400  3078.000
# 4    Alphington      3    h         Jellis 2016-09-03     6.400  3078.000
#
#    Bedroom  Bathroom   Car  Landsize  BuildingArea  YearBuilt  \
# 0    3.000     2.000 1.000   303.000       225.000   2016.000
# 1    2.000     1.000 0.000   120.000        82.000   1900.000
# 2    2.000     1.000 0.000   159.000           NaN        NaN
# 3    3.000     2.000 4.000   853.000       263.000   1930.000
# 4    3.000     2.000 2.000   208.000           NaN   2013.000
#
#               Regionname  Propertycount    Price  TotalSpace
# 0   Western Metropolitan           3464   840000       9.000
# ...

# %%
sns.scatterplot(data=data,x=data['TotalSpace'],y=data['Price'])
# Out:
# <Axes: xlabel='TotalSpace', ylabel='Price'>

# %%
sns.lmplot(data=data,x='TotalSpace',y='Price',height=5,aspect=2)
plt.xlim(0,55)
plt.show()

# %%
sns.scatterplot(data=data,x='Distance',y='Price')
# Out:
# <Axes: xlabel='Distance', ylabel='Price'>

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=data,x='Distance',y='Price',ci=False)
# Out:
# C:\Users\shahra\AppData\Local\Temp\ipykernel_20576\505740421.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=data,x='Distance',y='Price',ci=False)
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Distance', ylabel='Price'>

# %%
data['Distance_bin']=pd.cut(data['Distance'],bins=[0,15,20,50],labels=['Nearby','Moderately Close','Far'], right = False)

# %%
data.head()
# Out:
#          Suburb  Rooms Type        SellerG       Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson 2016-09-03    13.500  3042.000
# 1   Albert Park      2    h  hockingstuart 2016-09-03     3.300  3206.000
# 2   Albert Park      2    h        Thomson 2016-09-03     3.300  3206.000
# 3    Alphington      4    h          Brace 2016-09-03     6.400  3078.000
# 4    Alphington      3    h         Jellis 2016-09-03     6.400  3078.000
#
#    Bedroom  Bathroom   Car  Landsize  BuildingArea  YearBuilt  \
# 0    3.000     2.000 1.000   303.000       225.000   2016.000
# 1    2.000     1.000 0.000   120.000        82.000   1900.000
# 2    2.000     1.000 0.000   159.000           NaN        NaN
# 3    3.000     2.000 4.000   853.000       263.000   1930.000
# 4    3.000     2.000 2.000   208.000           NaN   2013.000
#
#               Regionname  Propertycount    Price  TotalSpace Distance_bin
# ...

# %%
sns.boxplot(data=data,x='Distance_bin',y='Price')
# Out:
# D:\Software\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='Distance_bin', ylabel='Price'>

# %%
sns.boxplot(data=data,x='Distance_bin',y='Price',showfliers=False)
# Out:
# D:\Software\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='Distance_bin', ylabel='Price'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  datetime64[ns]
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(4)
# ...

# %%
year_of_sale=data['Date'].dt.year
year_of_sale
# Out:
# 0        2016
# 1        2016
# 2        2016
# 3        2016
# 4        2016
#          ...
# 27109    2017
# 27110    2017
# 27111    2017
# 27112    2017
# 27113    2017
# Name: Date, Length: 27114, dtype: int32

# %%
data['Age_of_property']=year_of_sale-data['YearBuilt']
data['Age_of_property']
# Out:
# 0         0.000
# 1       116.000
# 2           NaN
# 3        86.000
# 4         3.000
#           ...
# 27109    58.000
# 27110    27.000
# 27111    22.000
# 27112       NaN
# 27113    57.000
# Name: Age_of_property, Length: 27114, dtype: float64

# %%
data.head()
# Out:
#          Suburb  Rooms Type        SellerG       Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson 2016-09-03    13.500  3042.000
# 1   Albert Park      2    h  hockingstuart 2016-09-03     3.300  3206.000
# 2   Albert Park      2    h        Thomson 2016-09-03     3.300  3206.000
# 3    Alphington      4    h          Brace 2016-09-03     6.400  3078.000
# 4    Alphington      3    h         Jellis 2016-09-03     6.400  3078.000
#
#    Bedroom  Bathroom   Car  Landsize  BuildingArea  YearBuilt  \
# 0    3.000     2.000 1.000   303.000       225.000   2016.000
# 1    2.000     1.000 0.000   120.000        82.000   1900.000
# 2    2.000     1.000 0.000   159.000           NaN        NaN
# 3    3.000     2.000 4.000   853.000       263.000   1930.000
# 4    3.000     2.000 2.000   208.000           NaN   2013.000
#
#               Regionname  Propertycount    Price  Age_of_property
# 0   Western Metropolitan           3464   840000            0.000
# ...

# %%
data[data['Age_of_property']<0]
# Out:
#                  Suburb  Rooms Type   SellerG       Date  Distance  Postcode  \
# 286    Avondale Heights      3    t    Nelson 2016-12-03    10.500  3034.000
# 13861         Bentleigh      3    h  Woodards 2018-03-17    11.400  3204.000
# 15240         Reservoir      4    h     Barry 2016-09-17    11.200  3073.000
# 19472       Keilor East      3    h    Nelson 2016-04-23    12.800  3033.000
# 21336     Brighton East      2    h    Buxton 2016-09-24    10.700  3187.000
# 24908           Newport      3    h       Jas 2016-05-28     8.400  3015.000
# 27080        Heidelberg      3    h     Miles 2016-07-30    10.600  3084.000
#
#        Bedroom  Bathroom   Car  Landsize  BuildingArea  YearBuilt  \
# 286      3.000     3.000 1.000   557.000       181.000   2017.000
# 13861    3.000     1.000 4.000   635.000       242.000   2019.000
# 15240    3.000     2.000 2.000   834.000       129.000   2017.000
# 19472    3.000     2.000 1.000   630.000       126.000   2017.000
# ...

# %%
sns.lineplot(data=data,x=data['Age_of_property'],y=data['Price'])
# Out:
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age_of_property', ylabel='Price'>

# %%
sns.lineplot(data=data,x=data['Age_of_property'],y=data['Price'],ci=False)
# Out:
# C:\Users\shahra\AppData\Local\Temp\ipykernel_6968\890679628.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=data,x=data['Age_of_property'],y=data['Price'],ci=False)
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age_of_property', ylabel='Price'>

# %%
sns.relplot(data=data,x=data['Age_of_property'],y=data['Price'],col=data['Regionname'])

# %%
sns.relplot(data=data,x=data['Age_of_property'],y=data['Price'],col=data['Regionname'],kind='line',col_wrap=4,ci=False)
# Out:
# D:\Software\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Software\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.boxplot(data=data,x=data['Type'],y=data['Price'])
# Out:
# <Axes: xlabel='Type', ylabel='Price'>

# %%
sns.boxplot(data=data,x=data['Type'],y=data['Price'],showfliers=False)
